# %% [markdown]
# # Walking Speed
#
# ├─ during walking, the robot acts as an inverted pendulum. natural frequency determines the walking speed

# %%
import numpy as np

g = 9.81   # m/s^2
h_com = 0.31    # m (COM height)

# natural frequency of inverted pendulum
omega_n = np.sqrt(g/h_com)

# natural period
T_n = 2*np.pi / omega_n

# natural frequency 
f_n = 1 / T_n

# %% [markdown]
# # Maximum step length from kinematic constraints
# Theory: step length is limited by hip joint range and foot geometry
