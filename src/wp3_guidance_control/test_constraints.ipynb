# %% [markdown]
# # Test Environment
# initialise controller and import constraints

# %%
"""
File: webots_simulation/controllers/test_constraints/test_constraints.ipynb

controller thaty verifies that robot_constraints.py 
accurately documents the NaoV6.proto implementation.
"""

from controller import Robot, Motor, PositionSensor
import sys
import os

# Add path to robot_constraints module
sys.path.append(os.path.join(os.path.dirname(__file__), '..', '..', '..', 'src', 'wp3_guidance_control'))

# Import our documentation
from robot_constraints import NAO6Constraints

# Initialise robot
robot = ... # Create Robot instance
timestep = ... # Get basic timestep as integer

print("="*70)
print("NAO6 CONSTRAINT VERIFICATION TEST SUITE")
print("="*70)
print(f"Timestep: {timestep} ms")
print()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 8
#       1 """
#       2 File: webots_simulation/controllers/test_constraints/test_constraints.ipynb
#       3
#       4 controller thaty verifies that robot_constraints.py
#       5 accurately documents the NaoV6.proto implementation.
#       6 """
# ----> 8 from controller import Robot, Motor, PositionSensor
#       9 import sys
#      10 import os
#
# ModuleNotFoundError: No module named 'controller'
